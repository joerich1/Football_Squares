# %% [markdown]
# # Analytics Day 2024: Football Squares
#
# **Class:** Discrete Math
# **Authors:** Joseph Richardson & Mohsin MD Abdul Karim
# **Date:** 10/9
#
# ---
#
# ### **About The Game**
# Football Squares is a popular game played during football games, often at parties or gatherings. The game involves a 10x10 grid where each participant buys one or more squares. Each row and column of the grid is assigned a number (0 through 9), corresponding to the last digit of the score for each team. After each quarter, the last digits of the teams' scores are used to find the corresponding square, and the owner of that square wins.
#
# Source: [wikiHow article on Football Squares](https://www.wikihow.com/Play-Football-Squares)
#
# ---
#
# ### **Data**
# This dataset includes 5,412 NFL regular season games from 1978 to 2023, detailing:
#
# - **Team Names & Scoring**:
#   - **Home Team**: `home_name`, `home_q1`, `home_q2`, `home_q3`, `home_q4`, `home_final`
#   - **Away Team**: `away_name`, `away_q1`, `away_q2`, `away_q3`, `away_q4`, `away_final`
#   - Scores are broken down by quarter, with overtime points added to the final score.
#
# - **Season Information**:
#   - **Year**: The season year of each game, ranging from 1978 to 2023.
#   - **Week**: The specific week within the regular season when the game occurred.
#
# Data was collected from [Football DB](https://www.footballdb.com/seasons/index.html) on 10/9.

# %% [markdown]
# ### IMPORTS

# %%
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import pandas as pd
import numpy as np
import sys

# Add the src/ folder to the Python path
sys.path.append(str(Path().resolve() / "src"))

from utils import create_frequency_matrices, create_fair_value_matrices, create_hm

games = pd.read_csv("data/nfl box scores.csv")

games_pre94 = pd.read_csv("data/nfl box scores 2.csv")
games_pre94.drop(["home_q5", "away_q5"], axis=1, inplace=True)
games_pre94.rename(columns={'home_team': 'home_name', 'away_team': 'away_name', "season": "year"},
                   inplace=True)
games_pre94 = games_pre94[games_pre94["year"] <= 1993]

games = pd.concat([games_pre94, games], ignore_index=True)

games.head()
# Out:
#                                home_name  home_q1  home_q2  home_q3  home_q4  \
# 0    Tampa Bay BuccaneersTampa Bay (0-1)        7        3        0        3
# 1             Detroit LionsDetroit (0-1)        0        0        7        0
# 2           Atlanta FalconsAtlanta (1-0)        0       14        3        3
# 3     Cincinnati BengalsCincinnati (0-1)        0        9        0       14
# 4  Philadelphia EaglesPhiladelphia (0-1)        0        0        0       14
#
#    home_final                            away_name  away_q1  away_q2  away_q3  \
# 0          13       New York GiantsNY Giants (1-0)        7        3        6
# 1           7     Green Bay PackersGreen Bay (1-0)        6        0        7
# 2          20          Houston OilersHouston (0-1)        7        0        7
# 3          23  Kansas City ChiefsKansas City (1-0)        7       10        7
# 4          14    Los Angeles RamsLos Angeles (1-0)        3        3        0
#
# ...

# %% [markdown]
# ### PRE-PREOCESSING

# %%
# Cumulative sums per quarter.
df = games.copy()
#df[["home_q2", "home_q3"]] = df.iloc[:, 2:3].cumsum()
for quarter in range(2, 5):
    for home_away in ["home", "away"]:
        df[f"{home_away}_q{quarter}"] = df[f"{home_away}_q{quarter-1}"] + df[f"{home_away}_q{quarter}"]

df_games = df.copy()
df_games.head()
# Out:
#                                home_name  home_q1  home_q2  home_q3  home_q4  \
# 0    Tampa Bay BuccaneersTampa Bay (0-1)        7       10       10       13
# 1             Detroit LionsDetroit (0-1)        0        0        7        7
# 2           Atlanta FalconsAtlanta (1-0)        0       14       17       20
# 3     Cincinnati BengalsCincinnati (0-1)        0        9        9       23
# 4  Philadelphia EaglesPhiladelphia (0-1)        0        0        0       14
#
#    home_final                            away_name  away_q1  away_q2  away_q3  \
# 0          13       New York GiantsNY Giants (1-0)        7       10       16
# 1           7     Green Bay PackersGreen Bay (1-0)        6        6       13
# 2          20          Houston OilersHouston (0-1)        7        7       14
# 3          23  Kansas City ChiefsKansas City (1-0)        7       17       24
# 4          14    Los Angeles RamsLos Angeles (1-0)        3        6        6
#
# ...

# %% [markdown]
# ### CREATE FREQUENCY & OPTIMAL SQUARE PRICE BOARDS

# %%
print("Rows: Home, Columns: Away\n")
frequency_matrices = create_frequency_matrices(df.copy())
fair_value_matrices = create_fair_value_matrices(mat=frequency_matrices, board_value=100)

fair_value_matrices[3]
# Out:
# Rows: Home, Columns: Away
# array([[2.03086   , 1.04379396, 0.60131609, 2.71159519, 2.20104379,
#         0.53324257, 1.33877921, 3.41502156, 0.63535285, 0.83957341],
#        [1.36147039, 0.68073519, 0.31767642, 1.04379396, 2.03086   ,
#         0.29498525, 0.5899705 , 1.7699115 , 0.77149989, 0.40844112],
#        [0.54458816, 0.39709553, 0.03403676, 0.4197867 , 0.4197867 ,
#         0.32902201, 0.31767642, 0.7601543 , 0.20422056, 0.23825732],
#        [2.80235988, 0.95302927, 0.20422056, 1.0097572 , 1.31608804,
#         0.30633084, 1.14590424, 2.25777173, 0.49920581, 0.47651464],
#        [3.12003631, 2.17835262, 0.70342637, 2.14431586, 2.00816882,
#         0.65804402, 1.50896301, 3.58520536, 1.11186748, 0.96437486],
#        [0.68073519, 0.52189698, 0.13614704, 0.65804402, 0.47651464,
#         0.09076469, 0.27229408, 0.86226458, 0.31767642, 0.22691173],
#        [1.47492625, 0.5105514 , 0.22691173, 1.32743363, 0.7601543 ,
# ...

# %% [markdown]
# ### PLOTS

# %%
"""# Define an off-white/eggshell color map for the squares
single_color_cmap = ListedColormap(["#fff4c8"])  # Off-white eggshell color

# Define labels for the heatmap
labels = np.array([[f"{y}-{x}" for x in range(10)] for y in range(10)])

# Create a matrix with the same number to get a uniform color
uniform_matrix = np.full((10, 10), 1)  # Filling with the number 1 for uniform color

# Create the plot
fig, ax = plt.subplots(figsize=(11, 11))
sns.heatmap(
    uniform_matrix, ax=ax, cmap=single_color_cmap,  
    cbar=False, square=True, linewidths=0.1, annot=labels, fmt="s",
    xticklabels=False, yticklabels=False,
    annot_kws={"fontsize": 20, "color": "black", "fontname": "Palatino", "fontweight": "bold"}  # Black text
)

# Set title with specified font
plt.title("Figure 1: Number Format: Home - Away", fontname="Palatino", fontsize=20)

# Remove spines and adjust ticks
for spine in ax.spines.values():
    spine.set_visible(False)
ax.tick_params(left=False, bottom=False)

# Save the figure
plt.savefig("plots/fig1_number_format.png")
plt.show()

# %%
# FIGURES 2 & 3

color = "gold"
digit_counts = {i: 0 for i in range(10)}

# Count each digit based on home and away frequency
for home_digit in range(10):
    for away_digit in range(10):
        count = frequency_matrices[3, home_digit, away_digit]
        digit_counts[home_digit] += count
        digit_counts[away_digit] += count

digit_distribution = pd.DataFrame.from_dict(digit_counts, orient='index', columns=['Frequency'])
digit_distribution['Proportion'] = digit_distribution['Frequency'] / digit_distribution['Frequency'].sum()

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(40, 12))

colors = ["#ffffff", "#ffffff", "gold"]  # White to Gold gradient
cmap = LinearSegmentedColormap.from_list("GoldToWhite", colors)

sns.heatmap(
    frequency_matrices[3], ax=ax1, cmap=cmap, square=True,
    annot=True, annot_kws={"size": 20, "color": "black", "fontname": "Palatino"}, fmt="d",
    center=np.median(frequency_matrices[3]), cbar=True, linewidths=0.5)
   

ax1.set_title("Figure 2: Frequencies for Football Squares, 1978 - 2023", fontname="Palatino", fontsize=24, pad=20)
ax1.set_xlabel("Away Team", fontname="Palatino", fontsize=20, labelpad=15)
ax1.set_ylabel("Home Team", fontname="Palatino", fontsize=20, labelpad=15)

import matplotlib.patches as patches

ax1.add_patch(patches.Rectangle(
    (0, 0),
    10, 10,
    fill=False,
    edgecolor="black",
    linewidth=2
))

ax1.tick_params(axis='both', which='major', labelsize=18)

sns.barplot(y=digit_distribution.index, x=digit_distribution['Proportion'], orient='h', color=color, ax=ax2)

ax2.set_title("Figure 3: Football Squares Digit Distribution", fontname="Palatino", fontsize=24, pad=20)
ax2.set_ylabel("Digit", fontname="Palatino", fontsize=20, labelpad=10)

x_ticks = np.arange(0, 0.20, 0.02)  # 0 to 0.16 in steps of 0.02
ax2.set_xlabel("Proportion", fontname="Palatino", fontsize=20, labelpad=10)
ax2.set_xticks(x_ticks)
ax2.set_xticklabels([f"{tick:.2f}" for tick in x_ticks], fontname="Palatino", fontsize=16)

ax2.tick_params(axis='both', which='major', labelsize=18)
ax2.set_yticks(range(10))
ax2.set_yticklabels(range(10))
ax2.axvline(x=0.10, color='black', linestyle='--')  # Uniform distribution line

# Adjust space between the plots and layout
plt.subplots_adjust(wspace=-.01)

plt.savefig("plots/fig2_fig3 digits.png")
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(60, 12))

# FIGURE 4: OPTIMAL SQUARE PRICES
title4 = "Figure 4: Optimal Square Prices, 1978 - 2023"
colors = ["#ffffff", "#ffffff", "#ffcc00"]
cmap = LinearSegmentedColormap.from_list("GoldToWhite", colors)

sns.heatmap(
    fair_value_matrices[3], ax=ax1, cmap=cmap, square=True,
    annot=True, annot_kws={"size": 20, "color": "black", "fontname": "Palatino"}, fmt=".2f",
    center=np.median(fair_value_matrices[3]), cbar=True, linewidths=0.5
)
ax1.set_title(title4, fontname="Palatino", fontsize=24, pad=20)
ax1.set_xlabel("Away Team", fontname="Palatino", fontsize=20, labelpad=15)
ax1.set_ylabel("Home Team", fontname="Palatino", fontsize=20, labelpad=15)
ax1.add_patch(patches.Rectangle((0, 0), 10, 10, fill=False, edgecolor="black", linewidth=2))
ax1.tick_params(axis='both', which='major', labelsize=18)

# FIGURE 5: HOME / AWAY BIAS
corrected_osp = (fair_value_matrices[3] + fair_value_matrices[3].T) / 2
title5 = "Figure 5: Bias-Adjusted Optimal Square Prices, 1978 - 2023"
sns.heatmap(
    corrected_osp, ax=ax2, cmap=cmap, square=True,
    annot=True, annot_kws={"size": 20, "color": "black", "fontname": "Palatino"}, fmt=".2f",
    center=np.median(corrected_osp), cbar=True, linewidths=0.5
)
ax2.set_title(title5, fontname="Palatino", fontsize=24, pad=20)
ax2.set_xlabel("Away Team", fontname="Palatino", fontsize=20, labelpad=15)
ax2.set_ylabel("Home Team", fontname="Palatino", fontsize=20, labelpad=15)
ax2.add_patch(patches.Rectangle((0, 0), 10, 10, fill=False, edgecolor="black", linewidth=2))
ax2.tick_params(axis='both', which='major', labelsize=18)

# FIGURE 6: BEFORE / AFTER 94
df1 = games[games["year"] <= 1993].copy()
df2 = games[games["year"] > 1993].copy()

freq_mat1 = create_frequency_matrices(df1)
freq_mat2 = create_frequency_matrices(df2)

fv_mat1 = create_fair_value_matrices(mat=freq_mat1, board_value=100)
fv_mat2 = create_fair_value_matrices(mat=freq_mat2, board_value=100)

corrected_fv1 = (fv_mat1[3] + fv_mat1[3].T) / 2
corrected_fv2 = (fv_mat2[3] + fv_mat2[3].T) / 2
diff = corrected_fv2 - corrected_fv1

def annotate_cells(data, text_color_threshold=0.5):
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            cell_value = data[i, j]
            color = "white" if cell_value < text_color_threshold else "black"
            plt.text(j + 0.5, i + 0.5, f"{cell_value:.2f}",
                     ha="center", va="center", color=color, fontsize=10)

title6 = "Figure 6: Bias-Adjusted Differences, Before and After 1994"
colors = ["#000000", "#ffffff", "#ffcc00"]
cmap = LinearSegmentedColormap.from_list("BlackWhiteGold", colors)

sns.heatmap(
    diff, ax=ax3, cmap=cmap, square=True,
    annot=True, annot_kws={"size": 20, "fontname": "Palatino"}, fmt=".2f",
    center=np.median(diff), cbar=True, linewidths=0.5
)
ax3.set_title(title6, fontname="Palatino", fontsize=24, pad=20)
ax3.set_xlabel("Away Team", fontname="Palatino", fontsize=20, labelpad=15)
ax3.set_ylabel("Home Team", fontname="Palatino", fontsize=20, labelpad=15)
ax3.add_patch(patches.Rectangle((0, 0), 10, 10, fill=False, edgecolor="black", linewidth=2))
ax3.tick_params(axis='both', which='major', labelsize=18)

# Adjust space between plots
plt.subplots_adjust(wspace=-0.4)
plt.savefig("plots/fig4_fig5_fig6.png")
plt.show()

# %% [markdown]
# ### T-TESTS

# %%
# MODIFIED T
from scipy.stats import t

def custom_ttest(mat, k):
    flat_ind = np.argpartition(np.abs(mat).flatten(), -k)[-k:]
    indices_2d = np.array(np.unravel_index(flat_ind, np.abs(mat).shape)).T
    top_diffs = mat[tuple(indices_2d.T)]
    
    mean_diff = np.mean(top_diffs)
    std_dev_full = np.std(mat, ddof=1)
    n = len(top_diffs)

    t_stat = mean_diff / (std_dev_full / np.sqrt(n))

    p_value = 2 * t.sf(np.abs(t_stat), df=n-1)

    return t_stat, p_value

mat = diff[3]
t_stat, p_value = custom_ttest(mat, k=10)
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -1.9873126365179423
# p-value: 0.07813410777440952

# %% [markdown]
# ### HOME VS AWAY BIAS

# %%
# H0: The tables with biases removed before 93 are the same as after 93
t_stat, p_value = custom_ttest(diff, k=37)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -2.1108536305385135
# p-value: 0.041796496400296965
